# %%
import numpy as np
import pandas as pd
import matplotlib as plt 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
red_wine =  pd.read_csv("winequality-red.csv", sep = ";")
red_wine.shape
# Out:
# (1599, 12)

# %%
white_wine =  pd.read_csv("winequality-white.csv", sep = ";")
white_wine.shape
# Out:
# (4898, 12)

# %%
white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# total sulfur dioxide: those are higher in the white wine than in the red wine
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'red wine', 'white wine'
sizes = [1598,4897]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'white wine')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode, labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'red wine', 'white wine'
sizes = [1598,4897]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode, labels, autopct='%1.1f%%', shadow=True, startangle=80)
ax1.axis('square')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
red_wine['quality label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
red_wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
red_wine = red_wine.copy()
red_wine.rename(columns={"quality_label":"quality label"}, inplace=True)

# %%
white_wine['quality label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
white_wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
sns.histplot(data=red_wine, x = 'quality_label').set_title('Red Wine')
# Out:
# Text(0.5, 1.0, 'Red Wine')

# %%
sns.histplot(data=white_wine, x = 'quality_label').set_title('White Wine')
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (12,8)) # # Figure/grid size, basic construction for further plotting

# %%
sns.histplot(data=red_wine, x = 'quality_label', color='red').set_title('Red Wine')
sns.histplot(data=white_wine, x = 'quality_label', color='green').set_title('White Wine')
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8), sharey = True)

sns.histplot(data=red_wine, x = 'quality_label', ax= axes[1], color= 'red').set_title('Red Wine')
sns.histplot(data=white_wine, x = 'quality_label', ax= axes[0], color= 'green').set_title('White Wine')
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8), sharey=True)

sns.countplot(data=red_wine, x = 'quality_label', ax= axes[1], color= 'red').set_title('Red Wine')
sns.countplot(data=white_wine, x = 'quality_label', ax= axes[0], color= 'green').set_title('White Wine')
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8))

sns.boxplot(data=white_wine, palette='rainbow', x= 'quality label', y= 'alcohol', ax= axes[0], color= 'red').set_title('Alcohol in % for white wine')
sns.boxplot(data=red_wine, palette='rainbow', x= 'quality label', y='alcohol', ax= axes[1], color= 'green').set_title('Alcohol in % for red wine')
# Out:
# C:\Users\media\AppData\Local\Temp\ipykernel_20112\3565187958.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=white_wine, palette='rainbow', x= 'quality label', y= 'alcohol', ax= axes[0], color= 'red').set_title('Alcohol in % for white wine')
# C:\Users\media\AppData\Local\Temp\ipykernel_20112\3565187958.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=red_wine, palette='rainbow', x= 'quality label', y='alcohol', ax= axes[1], color= 'green').set_title('Alcohol in % for red wine')
# Text(0.5, 1.0, 'Alcohol in % for red wine')

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8))

sns.boxplot(data=white_wine, palette='rainbow', x= 'quality label', y= 'volatile acidity', ax= axes[0], color= 'red').set_title('White Wine')
sns.boxplot(data=red_wine, palette='rainbow', x= 'quality label', y='volatile acidity', ax= axes[1], color= 'green').set_title('Red Wine')
# Out:
# C:\Users\media\AppData\Local\Temp\ipykernel_20112\2726601623.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=white_wine, palette='rainbow', x= 'quality label', y= 'volatile acidity', ax= axes[0], color= 'red').set_title('White Wine')
# C:\Users\media\AppData\Local\Temp\ipykernel_20112\2726601623.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=red_wine, palette='rainbow', x= 'quality label', y='volatile acidity', ax= axes[1], color= 'green').set_title('Red Wine')
# Text(0.5, 1.0, 'Red Wine')

# %%
fig, axes = plt.subplots(nrows= 2 , ncols= 2, figsize = (10,8))

sns.boxplot(data=white_wine, palette='rainbow', x= 'quality label', y= 'volatile acidity', ax= axes[0,0], color= 'green')
sns.boxplot(data=white_wine, palette='rainbow', x= 'quality label', y='alcohol', ax= axes[0,1], color= 'green')
sns.boxplot(data=red_wine, palette='rainbow', x= 'quality label', y= 'volatile acidity', ax= axes[1,0], color= 'red')
sns.boxplot(data=red_wine, palette='rainbow', x= 'quality label', y='alcohol', ax= axes[1,1], color= 'red')
fig.text(0.5, 0.92,'White Wine', ha='center',fontsize=14)
fig.text(0.5, 0.47,'Red Wine', ha='center', fontsize=14)
fig.subplots_adjust(hspace=0.4)
# Out:
# C:\Users\media\AppData\Local\Temp\ipykernel_20112\2134574579.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=white_wine, palette='rainbow', x= 'quality label', y= 'volatile acidity', ax= axes[0,0], color= 'green')
# C:\Users\media\AppData\Local\Temp\ipykernel_20112\2134574579.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=white_wine, palette='rainbow', x= 'quality label', y='alcohol', ax= axes[0,1], color= 'green')
# C:\Users\media\AppData\Local\Temp\ipykernel_20112\2134574579.py:5: FutureWarning:
#
# ...

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8))
sns.histplot(white_wine, x='alcohol', ax=axes[0], kde=True).set_title('White Wine')
sns.histplot(red_wine, x='alcohol', ax=axes[1], kde=True, color='red').set_title('Red Wine')
# Out:
# Text(0.5, 1.0, 'Red Wine')

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8))

sns.boxplot(data=red_wine, palette='rainbow', x= 'quality_label', y= 'pH', ax= axes[1], color= 'red').set_title('Wine pH')
sns.boxplot(data=red_wine, palette='rainbow', x= 'quality_label', y='alcohol', ax= axes[0], color= 'green').set_title('Wine Alcohol in %')
# Out:
# C:\Users\media\AppData\Local\Temp\ipykernel_7292\2059963381.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=red_wine, palette='rainbow', x= 'quality_label', y= 'pH', ax= axes[1], color= 'red').set_title('Wine pH')
# C:\Users\media\AppData\Local\Temp\ipykernel_7292\2059963381.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=red_wine, palette='rainbow', x= 'quality_label', y='alcohol', ax= axes[0], color= 'green').set_title('Wine Alcohol in %')
# Text(0.5, 1.0, 'Wine Alcohol in %')

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8))

sns.violinplot(data=red_wine, palette='rainbow', x= 'quality_label', y= 'pH', ax= axes[1], color= 'red').set_title('Wine pH')
sns.violinplot(data=red_wine, palette='rainbow', x= 'quality_label', y='alcohol', ax= axes[0], color= 'green').set_title('Wine Alcohol in %')
# Out:
# C:\Users\media\AppData\Local\Temp\ipykernel_7292\119785209.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=red_wine, palette='rainbow', x= 'quality_label', y= 'pH', ax= axes[1], color= 'red').set_title('Wine pH')
# C:\Users\media\AppData\Local\Temp\ipykernel_7292\119785209.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=red_wine, palette='rainbow', x= 'quality_label', y='alcohol', ax= axes[0], color= 'green').set_title('Wine Alcohol in %')
# Text(0.5, 1.0, 'Wine Alcohol in %')

# %%
fig,axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8))
sns.stripplot(data=red_wine, x= 'quality_label', y= 'alcohol', ax= axes[1], color= 'red').set_title('Red Wine')
sns.stripplot(data=white_wine, x= 'quality_label', y='alcohol', ax= axes[0], color= 'green').set_title('White Wine')
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
sns.catplot(x= 'quality_label', y= 'alcohol', data = red_wine)

# %%
sns.catplot(x= 'quality_label', y= 'alcohol', data = white_wine)

# %%
sns.regplot(x= 'quality', y= 'alcohol', data = red_wine)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
fig,axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8))
sns.lineplot(data=red_wine, y="volatile acidity", x="quality", ax=axes[0], color='red').set_title('Red Wine')
sns.lineplot(data=white_wine, y="volatile acidity", x="quality", ax=axes[1]).set_title('White Wine')
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig,axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8))
sns.lineplot(data=red_wine, y="volatile acidity", x="quality", ax=axes[0], color='red')
sns.lineplot(data=red_wine, y="alcohol", x="quality", ax=axes[1])
fig.suptitle(' Red Wine ', fontsize=15)
# Out:
# Text(0.5, 0.98, ' Red Wine ')

# %%
sns.relplot(data=red_wine, y="alcohol", x="quality", kind='line', color='red')

# %%
sns.relplot(data=white_wine, y="volatile acidity", x="quality", kind='line')

# %%
sns.regplot(x= 'quality', y= 'alcohol', data = white_wine)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8), sharey=True)

sns.pointplot(data=red_wine, x= 'quality_label', y= 'pH', ax= axes[1], color= 'red').set_title('Wine pH')
sns.pointplot(data=white_wine, x= 'quality_label', y='pH', ax= axes[0], color= 'green').set_title('Wine pH')
# Out:
# Text(0.5, 1.0, 'Wine pH')

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8), sharey=True)

sns.lineplot(data=red_wine, x= 'quality_label', y= 'pH', ax= axes[1], color= 'red').set_title('Wine pH')
sns.lineplot(data=white_wine, x= 'quality_label', y='pH', ax= axes[0], color= 'green').set_title('Wine pH')
# Out:
# Text(0.5, 1.0, 'Wine pH')

# %%
sns.histplot(data=red_wine, x= 'quality_label', y= 'pH', axes[1], color= 'red')
sns.histplot(data=white_wine, x= 'quality_label', y='pH', axes[0], color= 'green')
# Out:
#   Cell In[25], line 1
#     sns.histplot(data=red_wine, x= 'quality_label', y= 'pH', axes[1], color= 'red')
#                                                                                   ^
# SyntaxError: positional argument follows keyword argument

# %%
red_wine.hist(bins=15, color='red', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
white_wine.hist(bins=15, color='green', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
sns.histplot(data=red_wine, x="residual sugar", bins= 10).set_title('Red Wine')
# Out:
# Text(0.5, 1.0, 'Red Wine')

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8), sharey=True)

sns.histplot(data=red_wine, ax=axes[1], x="residual sugar", bins= 10).set_title('Red Wine')
sns.histplot(data=white_wine, ax=axes[0], color='white', x="residual sugar",bins=10).set_title('White Wine')
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8))

sns.histplot(data=red_wine, ax=axes[1], x="residual sugar", bins= 10).set_title('Red Wine').axes.set_ylim(0,2500)
sns.histplot(data=white_wine, ax=axes[0], color='white', x="residual sugar",bins=10).set_title('White Wine').axes.set_ylim(0,2500)
# Out:
# (0.0, 2500.0)

# %%
fig, axes = plt.subplots(nrows= 1 , ncols= 2, figsize = (10,8), sharey=True)

sns.histplot(data=red_wine, ax=axes[1], x="residual sugar", bins= 10).set_title('Red Wine').axes.set_ylabel("Frequency")
sns.histplot(data=white_wine, ax=axes[0], color='white', x="residual sugar",bins=10).set_title('White Wine').axes.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
red_wine = red_wine.drop(axis=1, columns=['quality_label'])
corr = red_wine.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0, annot=True, fmt=".1f",
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right')
# Out:
# [Text(0.5, 0, 'fixed acidity'),
#  Text(1.5, 0, 'volatile acidity'),
#  Text(2.5, 0, 'citric acid'),
#  Text(3.5, 0, 'residual sugar'),
#  Text(4.5, 0, 'chlorides'),
#  Text(5.5, 0, 'free sulfur dioxide'),
#  Text(6.5, 0, 'total sulfur dioxide'),
#  Text(7.5, 0, 'density'),
#  Text(8.5, 0, 'pH'),
#  Text(9.5, 0, 'sulphates'),
#  Text(10.5, 0, 'alcohol'),
#  Text(11.5, 0, 'quality')]

# %%
red_wine = red_wine
corr = red_wine.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0, annot=True, fmt=".1f",
    cmap=sns.diverging_palette(20, 200, n=100),
    square=True)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right')
# Out:
# [Text(0.5, 0, 'fixed acidity'),
#  Text(1.5, 0, 'volatile acidity'),
#  Text(2.5, 0, 'citric acid'),
#  Text(3.5, 0, 'residual sugar'),
#  Text(4.5, 0, 'chlorides'),
#  Text(5.5, 0, 'free sulfur dioxide'),
#  Text(6.5, 0, 'total sulfur dioxide'),
#  Text(7.5, 0, 'density'),
#  Text(8.5, 0, 'pH'),
#  Text(9.5, 0, 'sulphates'),
#  Text(10.5, 0, 'alcohol'),
#  Text(11.5, 0, 'quality')]

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="white")

red_wine = red_wine 


# Compute the correlation matrix
corr = red_wine.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt=".1f")
# Out:
# <Axes: >

# %%
sns.jointplot(x= 'quality' , y= 'sulphates', data=red_wine).set_axis_labels()
plt.suptitle('Red Wine sulphates and quality')
plt.tight_layout()

# %%
sns.jointplot(x= 'quality' , y= 'sulphates', data=white_wine).set_axis_labels()
plt.suptitle('White Wine sulphates and quality')
plt.tight_layout()

# %%
                       
sns.scatterplot(data=red_wine, x="alcohol", y="sulphates", hue="quality_label", style='quality_label')
# Out:
# <Axes: xlabel='alcohol', ylabel='sulphates'>

# %%
from scipy import stats

F, p = stats.f_oneway(red_wine[red_wine['quality_label'] == 'low']['alcohol'],
red_wine[red_wine['quality_label'] == 'medium']['alcohol'],
red_wine[red_wine['quality_label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 204.6131430407679 	p-value: 7.92705886781999e-80

# %%
from scipy import stats

F, p = stats.f_oneway(white_wine[white_wine['quality_label'] == 'low']['alcohol'],
white_wine[white_wine['quality_label'] == 'medium']['alcohol'],
white_wine[white_wine['quality_label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 478.1628922043277 	p-value: 2.0647901873531918e-190

# %%
fig, axes = plt.subplots(nrows= 2 , ncols= 2, figsize = (10,8))

sns.lineplot(data=red_wine, ax=axes[0,0], x='quality', y="volatile acidity", color='red')
sns.lineplot(data=red_wine, ax=axes[0,1], x='quality', y="alcohol", color='red')
sns.lineplot(data=white_wine, ax=axes[1,0], x='quality', y="volatile acidity")
sns.lineplot(data=white_wine, ax=axes[1,1], x='quality', y="alcohol")
fig.text(0.5, 0.92,'Red Wine', ha='center',fontsize=14)
fig.text(0.5, 0.47,'White Wine', ha='center', fontsize=14)
fig.subplots_adjust(hspace=0.4)

# %%
fig, axes = plt.subplots(nrows= 2 , ncols= 2, figsize = (10,8))

sns.lineplot(data=red_wine, ax=axes[0,0], x='quality', y="volatile acidity", color='red')
sns.lineplot(data=red_wine, ax=axes[0,1], x='quality', y="alcohol", color='red')
sns.lineplot(data=white_wine, ax=axes[1,0], x='quality', y="volatile acidity")
sns.lineplot(data=white_wine, ax=axes[1,1], x='quality', y="alcohol")
fig.text(0.5, 0.92,'Red Wine', ha='center',fontsize=14)
fig.text(0.5, 0.47,'White Wine', ha='center', fontsize=14)
fig.subplots_adjust(hspace=0.4)

# %%
fig, axes = plt.subplots(nrows= 2 , ncols= 2, figsize = (10,8))

sns.lineplot(data=red_wine, ax=axes[0,0], x='quality', y="volatile acidity", color='red')
sns.lineplot(data=red_wine, ax=axes[0,1], x='quality', y="alcohol", color='red')
sns.lineplot(data=white_wine, ax=axes[1,0], x='quality', y="volatile acidity")
sns.lineplot(data=white_wine, ax=axes[1,1], x='quality', y="alcohol")
fig.text(0.5, 0.92,'Red Wine', ha='center',fontsize=14)
fig.text(0.5, 0.50,'White Wine', ha='center', fontsize=14)
fig.subplots_adjust(top=0.85, bottom=0.2, hspace=0.5)

# %%
fig, axes = plt.subplots(2,2, figsize=(10,8))
